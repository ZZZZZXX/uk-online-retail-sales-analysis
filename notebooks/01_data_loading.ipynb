# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /Users/xizheji/Documents/UCI_Online_Retail_Project/notebooks
# ['~$I ONLINE RETAIL REPORT.docx', 'UCI ONLINE RETAIL REPORT.docx', '.ipynb_checkpoints', '01_data_loading.ipynb']

# %%
import os 
print(os.listdir("/Users/xizheji/Documents/UCI_Online_Retail_Project/data")
# Out:
#   Cell In[3], line 2
#     print(os.listdir("/Users/xizheji/Documents/UCI_Online_Retail_Project/data")
#                                                                                ^
# _IncompleteInputError: incomplete input

# %%
import os

print(os.listdir("../data"))

# %%
import pandas as pd
file_path = "../data/online_retail/xlsx"
df = pd.read_excel(file_path)
df.head()

# %%
import pandas as pd
file_path = "../data/online_retail.xlsx"
df = pd.read_excel(file_path)
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info
# Out:
# <bound method DataFrame.info of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[us]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(3), str(1)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.describe()
# Out:
#             Quantity                 InvoiceDate      UnitPrice     CustomerID
# count  541909.000000                      541909  541909.000000  406829.000000
# mean        9.552250  2011-07-04 13:34:57.156386       4.611114   15287.690570
# min    -80995.000000         2010-12-01 08:26:00  -11062.060000   12346.000000
# 25%         1.000000         2011-03-28 11:34:00       1.250000   13953.000000
# 50%         3.000000         2011-07-19 17:17:00       2.080000   15152.000000
# 75%        10.000000         2011-10-19 11:27:00       4.130000   16791.000000
# max     80995.000000         2011-12-09 12:50:00   38970.000000   18287.000000
# std       218.081158                         NaN      96.759853    1713.600303

# %%
df[df["Quantity"]<0].head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
(df["Quantity"] < 0).sum()
# Out:
# np.int64(10624)

# %%
df[df["UnitPrice"] <= 0].head()
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 622     536414     22139         NaN        56 2010-12-01 11:52:00        0.0
# 1970    536545     21134         NaN         1 2010-12-01 14:32:00        0.0
# 1971    536546     22145         NaN         1 2010-12-01 14:33:00        0.0
# 1972    536547     37509         NaN         1 2010-12-01 14:33:00        0.0
# 1987    536549    85226A         NaN         1 2010-12-01 14:34:00        0.0
#
#       CustomerID         Country
# 622          NaN  United Kingdom
# 1970         NaN  United Kingdom
# 1971         NaN  United Kingdom
# 1972         NaN  United Kingdom
# 1987         NaN  United Kingdom

# %%
(df["UnitPrice"] <= 0).sum()
# Out:
# np.int64(2517)

# %%
df_clean = df[
    (df["Quantity"] > 0) &
    (df["UnitPrice"] > 0) &
    (df["CustomerID"].notnull())
    ].copy()

# %%
df_clean.shape
# Out:
# (397884, 8)

# %%
df_clean.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df_clean.describe()
# Out:
#             Quantity                 InvoiceDate      UnitPrice     CustomerID
# count  397884.000000                      397884  397884.000000  397884.000000
# mean       12.988238  2011-07-10 23:41:23.511023       3.116488   15294.423453
# min         1.000000         2010-12-01 08:26:00       0.001000   12346.000000
# 25%         2.000000         2011-04-07 11:12:00       1.250000   13969.000000
# 50%         6.000000         2011-07-31 14:39:00       1.950000   15159.000000
# 75%        12.000000         2011-10-20 14:33:00       3.750000   16795.000000
# max     80995.000000         2011-12-09 12:50:00    8142.750000   18287.000000
# std       179.331775                         NaN      22.097877    1713.141560

# %%
df_clean["CustomerID"] = df_clean["CustomerID"].astype(int)

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 397884 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397884 non-null  object
#  1   StockCode    397884 non-null  object
#  2   Description  397884 non-null  object
#  3   Quantity     397884 non-null  int64
#  4   InvoiceDate  397884 non-null  datetime64[us]
#  5   UnitPrice    397884 non-null  float64
#  6   CustomerID   397884 non-null  int64
#  7   Country      397884 non-null  str
# dtypes: datetime64[us](1), float64(1), int64(2), object(3), str(1)
# memory usage: 27.3+ MB

# %%
df_clean["TotalSales"] = df_clean["Quantity"] * df_clean["UnitPrice"]
df_clean.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalSales
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34

# %%
df_clean["TotalSales"].describe()
# Out:
# count    397884.000000
# mean         22.397000
# std         309.071041
# min           0.001000
# 25%           4.680000
# 50%          11.800000
# 75%          19.800000
# max      168469.600000
# Name: TotalSales, dtype: float64

# %%
total_sales = df_clean["TotalSales"].sum()
total_order = df_clean["InvoiceNo"].nunique()
total_customers = df_clean["CustomerID"].nunique()
total_products = df_clean["StockCode"].nunique()

print("TotalSales:£{:,.2f}".format(total_sales))
print("InvoiceNo:", total_order)
print("CustomerID:", total_customers)
print("StockCode:", total_products)
# Out:
# TotalSales:£8,911,407.90
# InvoiceNo: 18532
# CustomerID: 4338
# StockCode: 3665

# %%
sales_by_country = df_clean.groupby("Country")["TotalSales"].sum().sort_values(ascending=False)
sales_by_country.head(10)
# Out:
# Country
# United Kingdom    7308391.554
# Netherlands        285446.340
# EIRE               265545.900
# Germany            228867.140
# France             209024.050
# Australia          138521.310
# Spain               61577.110
# Switzerland         56443.950
# Belgium             41196.340
# Sweden              38378.330
# Name: TotalSales, dtype: float64

# %%
sales_by_country = sales_by_country.reset_index()
sales_by_country.head(10)
# Out:
#           Country   TotalSales
# 0  United Kingdom  7308391.554
# 1     Netherlands   285446.340
# 2            EIRE   265545.900
# 3         Germany   228867.140
# 4          France   209024.050
# 5       Australia   138521.310
# 6           Spain    61577.110
# 7     Switzerland    56443.950
# 8         Belgium    41196.340
# 9          Sweden    38378.330

# %%
df_clean["InvoiceMonth"] = df_clean["InvoiceDate"].dt.to_period("M")

# %%
monthly_sales = df_clean.groupby("InvoiceMonth")["TotalSales"].sum().reset_index()
monthly_sales
# Out:
#    InvoiceMonth   TotalSales
# 0       2010-12   572713.890
# 1       2011-01   569445.040
# 2       2011-02   447137.350
# 3       2011-03   595500.760
# 4       2011-04   469200.361
# 5       2011-05   678594.560
# 6       2011-06   661213.690
# 7       2011-07   600091.011
# 8       2011-08   645343.900
# 9       2011-09   952838.382
# 10      2011-10  1039318.790
# 11      2011-11  1161817.380
# 12      2011-12   518192.790

# %%
monthly_sales["InvoiceMonth"] = monthly_sales["InvoiceMonth"].astype(str)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.plot(monthly_sales["InvoiceMonth"], monthly_sales["TotalSales"], marker = "o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(rotation = 45)
plt.show()

# %%
monthly_sales
# Out:
#    InvoiceMonth   TotalSales
# 0       2010-12   572713.890
# 1       2011-01   569445.040
# 2       2011-02   447137.350
# 3       2011-03   595500.760
# 4       2011-04   469200.361
# 5       2011-05   678594.560
# 6       2011-06   661213.690
# 7       2011-07   600091.011
# 8       2011-08   645343.900
# 9       2011-09   952838.382
# 10      2011-10  1039318.790
# 11      2011-11  1161817.380
# 12      2011-12   518192.790

# %%
df_clean["InvoiceDate"].min(), df_clean["InvoiceDate"].max()
# Out:
# (Timestamp('2010-12-01 08:26:00'), Timestamp('2011-12-09 12:50:00'))

# %%
monthly_summary = df_clean.groupby("InvoiceMonth").agg(
    TotalSales = ("TotalSales", "sum"),
    Orders = ("InvoiceNo", "nunique"),
    Customers = ("CustomerID", "nunique")
).reset_index()

monthly_summary["AverageOrderValue"] = monthly_summary["TotalSales"] / monthly_summary["Orders"]
monthly_summary
# Out:
#    InvoiceMonth   TotalSales  Orders  Customers  AverageOrderValue
# 0       2010-12   572713.890    1400        885         409.081350
# 1       2011-01   569445.040     987        741         576.945329
# 2       2011-02   447137.350     997        758         448.482798
# 3       2011-03   595500.760    1321        974         450.795428
# 4       2011-04   469200.361    1149        856         408.355406
# 5       2011-05   678594.560    1555       1056         436.395215
# 6       2011-06   661213.690    1393        991         474.668837
# 7       2011-07   600091.011    1331        949         450.857258
# 8       2011-08   645343.900    1280        935         504.174922
# 9       2011-09   952838.382    1755       1266         542.927853
# 10      2011-10  1039318.790    1929       1364         538.786309
# 11      2011-11  1161817.380    2657       1664         437.266609
# 12      2011-12   518192.790     778        615         666.057571

# %%
monthly_summary.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceMonth       13 non-null     period[M]
#  1   TotalSales         13 non-null     float64
#  2   Orders             13 non-null     int64
#  3   Customers          13 non-null     int64
#  4   AverageOrderValue  13 non-null     float64
# dtypes: float64(2), int64(2), period[M](1)
# memory usage: 652.0 bytes

# %%
plt.figure(figsize = (12, 6))
plt.plot(monthly_summary["InvoiceMonth"].astype(str), monthly_summary["Orders"], marker = "o")
plt.title("Monthly Order Trend")
plt.xlabel("Month")
plt.ylabel("Number of Orders")
plt.xticks(rotation=45)
plt.show()

# %%
monthly_summary
# Out:
#    InvoiceMonth   TotalSales  Orders  Customers  AverageOrderValue
# 0       2010-12   572713.890    1400        885         409.081350
# 1       2011-01   569445.040     987        741         576.945329
# 2       2011-02   447137.350     997        758         448.482798
# 3       2011-03   595500.760    1321        974         450.795428
# 4       2011-04   469200.361    1149        856         408.355406
# 5       2011-05   678594.560    1555       1056         436.395215
# 6       2011-06   661213.690    1393        991         474.668837
# 7       2011-07   600091.011    1331        949         450.857258
# 8       2011-08   645343.900    1280        935         504.174922
# 9       2011-09   952838.382    1755       1266         542.927853
# 10      2011-10  1039318.790    1929       1364         538.786309
# 11      2011-11  1161817.380    2657       1664         437.266609
# 12      2011-12   518192.790     778        615         666.057571

# %%
plt.figure(figsize = (12, 6))
plt.plot(monthly_summary["InvoiceMonth"].astype(str), monthly_summary["Customers"], marker = "o")
plt.title("Monthly Customer Trend")
plt.xlabel("Month")
plt.ylabel("Number of Customers")
plt.xticks(rotation=45)
plt.show()

# %%
top_products = df_clean.groupby(["StockCode", "Description"])["TotalSales"].sum().sort_values(ascending = False).head(10)
top_products
# Out:
# StockCode  Description
# 23843      PAPER CRAFT , LITTLE BIRDIE           168469.60
# 22423      REGENCY CAKESTAND 3 TIER              142592.95
# 85123A     WHITE HANGING HEART T-LIGHT HOLDER    100448.15
# 85099B     JUMBO BAG RED RETROSPOT                85220.78
# 23166      MEDIUM CERAMIC TOP STORAGE JAR         81416.73
# POST       POSTAGE                                77803.96
# 47566      PARTY BUNTING                          68844.33
# 84879      ASSORTED COLOUR BIRD ORNAMENT          56580.34
# M          Manual                                 53779.93
# 23084      RABBIT NIGHT LIGHT                     51346.20
# Name: TotalSales, dtype: float64

# %%
non_product_codes = [
    "POST",
    "M",
    "D",
    "DOT",
    "BANK CHARGES",
    "AMAZONFEE",
    "CRUK",
    "C2",
    "S"]
df_products = df_clean[
    ~df_clean["StockCode"].astype(str).isin(non_product_codes)].copy()
df_products.shape
# Out:
# (396340, 10)

# %%
df_products[
    df_products["Description"].isin(["POSTAGE", "Manual"])]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, TotalSales, InvoiceMonth]
# Index: []

# %%
product_summary = df_products.groupby("StockCode").agg(
    Description = ("Description", "first"),
    TotalQuantity = ("Quantity", "sum"),
    TotalSales = ("TotalSales", "sum"),
    Orders = ("InvoiceNo", "nunique")
).reset_index()

product_summary["AverageUnitPrice"] = (
    product_summary["TotalSales"]
    / product_summary["TotalQuantity"])

# %%
top_products_by_quantity = product_summary.sort_values(
    "TotalQuantity",
    ascending=False
).head(10)
top_products_by_quantity
# Out:
#      StockCode                         Description  TotalQuantity  TotalSales  \
# 2329     23843         PAPER CRAFT , LITTLE BIRDIE          80995   168469.60
# 1927     23166      MEDIUM CERAMIC TOP STORAGE JAR          77916    81416.73
# 2499     84077   WORLD WAR 2 GLIDERS ASSTD DESIGNS          54415    13586.25
# 1018     22197                SMALL POPCORN HOLDER          49183    37226.43
# 3343    85099B             JUMBO BAG RED RETROSPOT          46181    85220.78
# 3349    85123A  WHITE HANGING HEART T-LIGHT HOLDER          36782   100603.50
# 2602     84879       ASSORTED COLOUR BIRD ORNAMENT          35362    56580.34
# 353      21212     PACK OF 72 RETROSPOT CAKE CASES          33693    16394.53
# 1849     23084                  RABBIT NIGHT LIGHT          27202    51346.20
# 1282     22492             MINI PAINT SET VINTAGE           26076    16039.24
#
#       Orders  AverageUnitPrice
# 2329       1          2.080000
# 1927     195          1.044930
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.barh(
    top_products_by_quantity["Description"].iloc[::-1], 
    top_products_by_quantity["TotalQuantity"].iloc[::-1]
)
plt.title("Top 10 Products by Quantity Sold")
plt.xlabel("Total Quantity Sold")
plt.ylabel("Product")
plt.tight_layout()
plt.show()

# %%
top_products_by_sales = product_summary.sort_values("TotalSales", ascending = False).head(10)
top_products_by_sales
# Out:
#      StockCode                         Description  TotalQuantity  TotalSales  \
# 2329     23843         PAPER CRAFT , LITTLE BIRDIE          80995   168469.60
# 1218     22423            REGENCY CAKESTAND 3 TIER          12402   142592.95
# 3349    85123A  WHITE HANGING HEART T-LIGHT HOLDER          36782   100603.50
# 3343    85099B             JUMBO BAG RED RETROSPOT          46181    85220.78
# 1927     23166      MEDIUM CERAMIC TOP STORAGE JAR          77916    81416.73
# 2406     47566                       PARTY BUNTING          15291    68844.33
# 2602     84879       ASSORTED COLOUR BIRD ORNAMENT          35362    56580.34
# 1849     23084                  RABBIT NIGHT LIGHT          27202    51346.20
# 1292     22502          PICNIC BASKET WICKER SMALL           1488    47366.20
# 2469     79321                       CHILLI LIGHTS           9650    46286.51
#
#       Orders  AverageUnitPrice
# 2329       1          2.080000
# 1218    1703         11.497577
# ...

# %%
plt.figure(figsize=(12,6))
plt.barh(
    top_products_by_sales["Description"].iloc[::-1], 
    top_products_by_sales["TotalSales"].iloc[::-1]
)
plt.title("Top 10 Products by Total Sales")
plt.xlabel("Total Sales")
plt.ylabel("Products")
plt.tight_layout()
plt.show()

# %%
quantity_threshold = product_summary["TotalQuantity"].quantile(0.75)
price_threshold = product_summary["AverageUnitPrice"].median()#也可以用.quantile(0.5)

high_volume_low_price = product_summary[
    (product_summary["TotalQuantity"] >= quantity_threshold) &
    (product_summary["AverageUnitPrice"] <= price_threshold)
].sort_values("TotalQuantity", ascending = False).head(10)

high_volume_low_price
# Out:
#      StockCode                         Description  TotalQuantity  TotalSales  \
# 1927     23166      MEDIUM CERAMIC TOP STORAGE JAR          77916    81416.73
# 2499     84077   WORLD WAR 2 GLIDERS ASSTD DESIGNS          54415    13586.25
# 1018     22197                SMALL POPCORN HOLDER          49183    37226.43
# 2602     84879       ASSORTED COLOUR BIRD ORNAMENT          35362    56580.34
# 353      21212     PACK OF 72 RETROSPOT CAKE CASES          33693    16394.53
# 1282     22492             MINI PAINT SET VINTAGE           26076    16039.24
# 1399     22616          PACK OF 12 LONDON TISSUES           25345     7266.71
# 840      21977  PACK OF 60 PINK PAISLEY CAKE CASES          24264    11629.70
# 37       17003                 BROCADE RING PURSE           22963     5980.05
# 999      22178     VICTORIAN GLASS HANGING T-LIGHT          22433    28776.51
#
#       Orders  AverageUnitPrice
# 1927     195          1.044930
# 2499     472          0.249678
# ...

# %%
sales_threshold = product_summary["TotalSales"].quantile(0.75)
price_threshold = product_summary["AverageUnitPrice"].quantile(0.75)

high_value_products = product_summary[
    (product_summary["TotalSales"] >= sales_threshold) &
    (product_summary["AverageUnitPrice"] >= price_threshold)
    ].sort_values("TotalSales", ascending = False).head(10)
high_value_products
# Out:
#      StockCode                        Description  TotalQuantity  TotalSales  \
# 1218     22423           REGENCY CAKESTAND 3 TIER          12402   142592.95
# 2406     47566                      PARTY BUNTING          15291    68844.33
# 1292     22502         PICNIC BASKET WICKER SMALL           1488    47366.20
# 2469     79321                      CHILLI LIGHTS           9650    46286.51
# 2046     23298                     SPOTTY BUNTING           7785    36173.95
# 2032     23284      DOORMAT KEEP CALM AND COME IN           5342    35913.85
# 2479     82484  WOOD BLACK BOARD ANT WHITE FINISH           5921    34478.01
# 1500     22720  SET OF 3 CAKE TINS PANTRY DESIGN            7020    33347.80
# 1731     22960           JAM MAKING SET WITH JARS           8151    32662.97
# 2005     23245         SET OF 3 REGENCY CAKE TINS           5856    26625.68
#
#       Orders  AverageUnitPrice
# 1218    1703         11.497577
# 2406    1379          4.502278
# ...

# %%
product_sales_ranking = product_summary.sort_values("TotalSales", ascending = False).copy()
top_10_product_share = (
    product_sales_ranking.head(10)["TotalSales"].sum()
    / product_sales_ranking["TotalSales"].sum()
    * 100
)
print(
    f"Top 10 products contributed "
    f"{top_10_product_share:.2f}% of product sales."
)
# Out:
# Top 10 products contributed 9.69% of product sales.

# %%
import math

top_20_product_count = math.ceil(len(product_sales_ranking) * 0.2)

top_20_product_share = (
    product_sales_ranking.head(top_20_product_count)["TotalSales"].sum()
    /product_sales_ranking["TotalSales"].sum()
    * 100
)

print("Number of products: ", len(product_sales_ranking))
print("Top 20% product count: ", top_20_product_count)
print(
    f"Top 20% of product contributed "
    f"{top_20_product_share:.2f}% of product sales."
)
# Out:
# Number of products:  3660
# Top 20% product count:  732
# Top 20% of product contributed 78.38% of product sales.

# %%
product_sales_ranking["CumulativeSalesShare"] = (
    product_sales_ranking["TotalSales"].cumsum()
    / product_sales_ranking["TotalSales"].sum()
    * 100
)
product_sales_ranking["ProductRankPercent"] = (
    range(1, len(product_sales_ranking) + 1)
)
product_sales_ranking["ProductRankPercent"]= (
    product_sales_ranking["ProductRankPercent"]
    / len(product_sales_ranking)
    * 100
)

# %%
product_sales_ranking = product_summary.sort_values(
    "TotalSales", ascending = False).reset_index(drop = True)

# %%
product_sales_ranking["CumulativeSalesShare"] = (
    product_sales_ranking["TotalSales"].cumsum()
    / product_sales_ranking["TotalSales"].sum()
    * 100
)

# %%
product_sales_ranking["ProductRankPercent"] = (
    range(1, len(product_sales_ranking) + 1)
)
product_sales_ranking["ProductRankPercent"] = (
    product_sales_ranking["ProductRankPercent"]
    / len(product_sales_ranking) * 100)

# %%
product_sales_ranking["CumulativeSalesShare"].max()
# Out:
# np.float64(99.99999999999997)

# %%
product_for_80_percent = product_sales_ranking[
    product_sales_ranking["CumulativeSalesShare"] >= 80
    ].iloc[0]
product_for_80_percent
# Out:
# StockCode                                           23212
# Description             HEART WREATH DECORATION WITH BELL
# TotalQuantity                                        2179
# TotalSales                                        2582.63
# Orders                                                145
# AverageUnitPrice                                 1.185236
# CumulativeSalesShare                            80.020121
# ProductRankPercent                              21.448087
# Name: 784, dtype: object

# %%
print(
    f"{product_for_80_percent['ProductRankPercent']:.2f}% "
    f"of products contributed 80% of product sales.")
# Out:
# 21.45% of products contributed 80% of product sales.

# %%
import math
top_20_product_count = math.ceil(
    len(product_sales_ranking) * 0.20)

top_20_product_share = (
    product_sales_ranking.head(top_20_product_count)["TotalSales"].sum()
    / product_sales_ranking["TotalSales"].sum()
    * 100)

print("Number of product: ", len(product_sales_ranking))
print("Top 20% product count: ", top_20_product_count)
print(
    f"Top 20% of product contributed: "
    f"{top_20_product_share:.2f}% of product sales."
)
# Out:
# Number of product:  3660
# Top 20% product count:  732
# Top 20% of product contributed: 78.38% of product sales.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12, 6))
plt.plot(
    product_sales_ranking["ProductRankPercent"],
    product_sales_ranking["CumulativeSalesShare"])
plt.axhline(y=80, linestyle = "--")
plt.axvline(
    x = product_for_80_percent["ProductRankPercent"],
    linestyle = "--")
plt.title("Cumulative Product Sales Contribution")
plt.xlabel("Percentage of Products")
plt.ylabel("Cumulative Sales Share")
plt.grid(True)
plt.show()

# %%
customer_summary = df_clean.groupby("CustomerID").agg(
    TotalSales = ("TotalSales", "sum"),
    Orders = ("InvoiceNo", "nunique"),
    TotalQuantity = ("Quantity", "sum")).reset_index()

customer_summary["AverageOrderValue"] = (
    customer_summary["TotalSales"]
    / customer_summary["Orders"])

customer_summary = customer_summary.sort_values("TotalSales", ascending = False).reset_index(drop = True)
customer_summary.head(10)
# Out:
#    CustomerID  TotalSales  Orders  TotalQuantity  AverageOrderValue
# 0       14646   280206.02      73         196915        3838.438630
# 1       18102   259657.30      60          64124        4327.621667
# 2       17450   194550.79      46          69993        4229.365000
# 3       16446   168472.50       2          80997       84236.250000
# 4       14911   143825.06     201          80265         715.547562
# 5       12415   124914.53      21          77374        5948.310952
# 6       14156   117379.63      55          57885        2134.175091
# 7       17511    91062.38      31          64549        2937.496129
# 8       16029    81024.84      63          40208        1286.108571
# 9       12346    77183.60       1          74215       77183.600000

# %%
top_customer_by_orders = customer_summary.sort_values("Orders", ascending = False).head(10)
top_customer_by_orders
# Out:
#     CustomerID  TotalSales  Orders  TotalQuantity  AverageOrderValue
# 27       12748    33719.73     209          25747         161.338421
# 4        14911   143825.06     201          80265         715.547562
# 22       17841    40991.57     124          23071         330.577177
# 14       13089    58825.83      97          31070         606.451856
# 80       14606    12156.65      93           6224         130.716667
# 13       15311    60767.90      91          38194         667.779121
# 85       12971    11189.91      86           9289         130.115233
# 0        14646   280206.02      73         196915        3838.438630
# 8        16029    81024.84      63          40208        1286.108571
# 34       13408    28117.04      62          16232         453.500645

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (12, 6))
plt.bar(
    top_customer_by_orders["CustomerID"].astype(str),
    top_customer_by_orders["Orders"])
plt.title("Top 10 Customers by Number of Orders")
plt.xlabel("Customer ID")
plt.ylabel("Number of Orders")
plt.xticks(rotation = 45)
plt.show()

# %%
top_customers_by_quantity = customer_summary.sort_values(
    "TotalQuantity", ascending = False).head(10)
top_customers_by_quantity
# Out:
#     CustomerID  TotalSales  Orders  TotalQuantity  AverageOrderValue
# 0        14646   280206.02      73         196915        3838.438630
# 3        16446   168472.50       2          80997       84236.250000
# 4        14911   143825.06     201          80265         715.547562
# 5        12415   124914.53      21          77374        5948.310952
# 9        12346    77183.60       1          74215       77183.600000
# 2        17450   194550.79      46          69993        4229.365000
# 7        17511    91062.38      31          64549        2937.496129
# 1        18102   259657.30      60          64124        4327.621667
# 12       13694    65039.62      50          63312        1300.792400
# 18       14298    51527.30      44          58343        1171.075000

# %%
customer_sales_ranking = customer_summary.sort_values("TotalSales", ascending = False).reset_index(drop = True)
customer_sales_ranking["CumulativeSalesShare"] = (
    customer_sales_ranking["TotalSales"].cumsum()
    / customer_sales_ranking["TotalSales"].sum()
    * 100)
customer_sales_ranking["CustomerRankPercent"] = (range(1, len(customer_sales_ranking) + 1))
customer_sales_ranking["CustomerRankPercent"]= (
    customer_sales_ranking["CustomerRankPercent"]
    / len(customer_sales_ranking)
    * 100)

# %%
customer_for_80_percent = customer_sales_ranking[customer_sales_ranking["CumulativeSalesShare"] >= 80].iloc[0]
print(
    f"{customer_for_80_percent["CustomerRankPercent"]:.2f}% "
    f"of customers contributed 80% of total sales.")
# Out:
# 26.12% of customers contributed 80% of total sales.

# %%
plt.figure(figsize = (12, 6))
plt.plot(
    customer_sales_ranking["CustomerRankPercent"],
    customer_sales_ranking["CumulativeSalesShare"])
plt.axhline(y = 80, linestyle = "--")
plt.axvline(
    x = customer_for_80_percent["CustomerRankPercent"],
    linestyle = "--")
plt.title("Cumulative Customer Sales Contribution")
plt.xlabel("Percentage of Customers")
plt.ylabel("Cumulative Sales Share (%)")
plt.grid(True)
plt.show()

# %%
# !pip install openpyxl

# %%
df_clean["TotalSales"] = df_clean["Quantity"] * df_clean["UnitPrice"]
df_clean.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalSales  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom       15.30
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 397884 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     397884 non-null  object
#  1   StockCode     397884 non-null  object
#  2   Description   397884 non-null  object
#  3   Quantity      397884 non-null  int64
#  4   InvoiceDate   397884 non-null  datetime64[us]
#  5   UnitPrice     397884 non-null  float64
#  6   CustomerID    397884 non-null  int64
#  7   Country       397884 non-null  str
#  8   TotalSales    397884 non-null  float64
#  9   InvoiceMonth  397884 non-null  period[M]
# dtypes: datetime64[us](1), float64(2), int64(2), object(3), period[M](1), str(1)
# memory usage: 33.4+ MB

# %%
df_clean["InvoiceMonth"].head()
# Out:
# 0    2010-12
# 1    2010-12
# 2    2010-12
# 3    2010-12
# 4    2010-12
# Name: InvoiceMonth, dtype: period[M]

# %%
df_export = df_clean.copy()
df_export["InvoiceMonth"] = (df_export["InvoiceMonth"].astype(str))

# %%
df_export.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 397884 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     397884 non-null  object
#  1   StockCode     397884 non-null  object
#  2   Description   397884 non-null  object
#  3   Quantity      397884 non-null  int64
#  4   InvoiceDate   397884 non-null  datetime64[us]
#  5   UnitPrice     397884 non-null  float64
#  6   CustomerID    397884 non-null  int64
#  7   Country       397884 non-null  str
#  8   TotalSales    397884 non-null  float64
#  9   InvoiceMonth  397884 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(2), object(3), str(2)
# memory usage: 33.4+ MB

# %%
df_export.to_excel("Online_Retail_Dashboard.xlsx", index = False, engine = "openpyxl")
print("Export Complete")
# Out:
# Export Complete

# %%
import os
os.path.getsize("Online_Retail_Dashboard.xlsx")
# Out:
# 22613636
